# %%
# -------------------------
# IMPORTS AND SETUP
# -------------------------

import os
import random
import numpy as np
import networkx as nx
import torch
import torch.nn.functional as F
import torch_geometric
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv, global_mean_pool
from torch_scatter import scatter_max

from rl_env_graph_obs_variable_action_space import GraphTraversalEnv
from collections import deque
import numpy as np
import random
import torch
import torch.nn.functional as F
from torch import optim
from collections import namedtuple, deque
#import range tqdm
from tqdm import tqdm
from tqdm import trange
from torch_geometric.loader import DataLoader
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv, global_mean_pool

from torch_geometric.nn import GCNConv, global_mean_pool, SAGPooling, global_add_pool, global_max_pool
from torch_geometric.data import Data
import torch_geometric.transforms as T
from torch_geometric.nn import GATConv
from torch.utils.tensorboard import SummaryWriter

import heapq  # For priority queue
import time
from agent_variable_action_space import Agent
from utils import preprocess_graph, convert_types, add_global_root_node, connect_components, remove_all_isolated_nodes
from networkx.drawing.nx_pydot import graphviz_layout
from matplotlib import pyplot as plt 

# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
from agent_variable_action_space import GraphQNetwork, GraphQNetworkNew

STATE_SPACE = 7
EDGE_ATTR_SIZE = 1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GraphQNetworkNew(STATE_SPACE, EDGE_ATTR_SIZE, 0).to(device)
model_path = "/root/ssh-rlkex/models/rl/VACTION_SPACE_GOAL_GraphQNetworkNew_20240229-070657/460_6.57.pt"
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
# -------------------------
# HYPERPARAMETERS
# -------------------------

def act(model, state, action_mask, goal, visited_subgraph, current_node):
    state = state
    action_mask = action_mask.to(device)
    goal = goal.to(device)
    goal = goal.unsqueeze(0)
    model.eval()
    x = state.x.to(device)
    edge_index = state.edge_index.to(device)
    edge_attr = state.edge_attr.to(device)
    current_node = torch.tensor([current_node], dtype=torch.long).to(device)

    with torch.no_grad():  # Wrap in no_grad
        action_values = model(x, edge_index, edge_attr, None, action_mask, goal, visited_subgraph, None, current_node)
    return_values = action_values.cpu()
    
    selected_action = torch.argmax(return_values).item()
    torch.cuda.empty_cache()
    return selected_action, return_values



def define_targets(graph):
    target_nodes_map = {}
    for node, attributes in graph.nodes(data=True):
        cat_value = attributes['cat']
        if cat_value >= 0 and cat_value <= 3: #Only take the encryption and initialization keys, ignore integrity keys
            target_nodes_map[node] = attributes['cat'] 
    return target_nodes_map

# %%
from root_heuristic_rf import GraphPredictor

root_detection_model_path="/root/ssh-rlkex/models/root_heuristic_model.joblib"
 
root_detector = GraphPredictor(root_detection_model_path)

# %%
def show_graph(graph, goal, current_node, neighbours_qvalues):
    #for all target nodes, if the value of target_nodes[node] is 0 then label is 'A', if 1 then label is 'B', etc.. up to 5 (F)
    labels = {}
    for node, attributes in graph.nodes(data=True):
        if attributes['cat'] >= 0:
            labels[str(node)] = chr(ord('A') + attributes['cat'])
            #if is goal concatenate with "G"
            if node == goal:
                labels[str(node)] = labels[str(node)] + " G"

        elif node == current_node:
            labels[str(node)] = "X"
        else:
            labels[str(node)] = ""
        #if node is a neighbou concatenate the qvalue
        if node in neighbours_qvalues:
            labels[str(node)] = f"{labels[str(node)]} : {neighbours_qvalues[node].item():.2f}"
    #set colors of target nodes to red
            
    #set colors of neighbours as a heatmap of the qvalues, closer to 1 is red, closer to 0 is blue
    colors = []
    for node, attributes in graph.nodes(data=True):
        if attributes['cat'] >= 0:
            colors.append((1, 0, 0))
        elif node == current_node:
            colors.append((0, 1, 0))
        elif node in neighbours_qvalues:
            
            min_qvalue = min(neighbours_qvalues.values()).item()
            max_qvalue = max(neighbours_qvalues.values()).item()


            qvalue = neighbours_qvalues[node] 

            #convert qvalue to regular float
            qvalue = qvalue.item()
            

            #normalize between 0 and 1 in case
            qvalue = 0 if max_qvalue == min_qvalue else (qvalue - min_qvalue) / (max_qvalue - min_qvalue)
            
            colors.append((qvalue, 0, 1 - qvalue))
        else:
            colors.append((0, 0, 0))
    
    G_temp = nx.DiGraph()
    G_temp.add_nodes_from(str(n) for n in graph.nodes())    
    G_temp.add_edges_from((str(u), str(v)) for u, v in graph.edges())
    #draw the graph with labels and colors
    pos = graphviz_layout(G_temp, prog='dot')
    nx.draw(G_temp, labels=labels, node_color=colors, pos = pos)
    plt.show()

# %%
SHOW_GAPH_TEST = False

# %%
def test_for_graph(file):
    """Basically the same as the training function, but without training"""
    graph = nx.read_graphml(file)
    graph = preprocess_graph(graph)

    #get all target_nodes, check if nodes has 'cat' = 1
    target_nodes = define_targets(graph=graph)
    episode_rewards = []
    #data = graph_to_data(graph)
    env = GraphTraversalEnv(graph, target_nodes,root_detector=root_detector, obs_is_full_graph=True)
    
    total_reward = 0
    total_key_found = 0

    for target in target_nodes:
        done = False

        goal = target_nodes[target]
        observation = env.reset()
        goal_one_hot = env.get_goal_one_hot(goal)
        env.set_target_goal(goal)
        display_graph = env.graph
        while not done:
            
            action_mask = env._get_action_mask()
            visited_subgraph = env.get_visited_subgraph()
            current_node = env.get_current_node()
            action, qvalues = act(model, observation, action_mask, goal_one_hot, visited_subgraph, current_node)
            node_qvalues_map = {}
            for i, qvalue in enumerate(qvalues):
                if action_mask[i] == 1:
                    node_qvalues_map[env.inverse_node_mapping[i]] = qvalue
            if SHOW_GAPH_TEST:
                show_graph(display_graph, target, env.current_node, node_qvalues_map)
            
            new_observation, reward, done, info, new_goal = env.step(action)
            total_reward += reward
            if done:
                if info["found_target"]:
                    total_key_found += 1
            
            observation = new_observation
    
    return total_reward, total_key_found, len(target_nodes)

# %%
FOLDER = "/root/ssh-rlkex/Test_Graphs"
#get all files in the folder recursively
all_files = []
for root, dirs, files in os.walk(FOLDER):
    for file in files:
        if file.endswith(".graphml"):
            all_files.append(os.path.join(root, file))


print(f"Total files: {len(all_files)}")
# Out:
# Total files: 200

# %%
#shuffle the files
random.shuffle(all_files)

nb_test_files = len(all_files)
test_files = all_files[:nb_test_files]

# %%
#Test for each file
print(f"Executing Testing ...")
test_rewards = []
test_success_rate = []
for i, file in enumerate(test_files):
    if file.endswith(".graphml"):
        print(f"[{i} / {nb_test_files}] : Executing Testing for {file}")
        reward, nb_found_keys, nb_keys = test_for_graph(file)
        print(f"Found {nb_found_keys} / {nb_keys} keys with a mean reward of {reward}")
        test_rewards.append(reward)
        test_success_rate.append(nb_found_keys / nb_keys)

print(f"Testing done with a mean reward of {np.mean(test_rewards)} and a success rate of {np.mean(test_success_rate)}")
# Out:
# Executing Testing ...
# [0 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_8_P1/64/28527-1643975243.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [1 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/17960-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [2 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/16/9132-1644320781.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [3 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/64/6830-1643986137.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [4 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/24/27067-1644344888.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [5 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_8_0_P1/64/2645-1644853880.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [6 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_8_P1/32/2815-1643978226.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [7 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/24/30674-1643984444.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [8 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/24/14098-1643984448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 269
# Number of edges in the graph: 268
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9962825278810409
# Depth of the graph: 8
# Number of neighbors of the root: 59
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of 0
# [9 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_7_8_P1/24/14844-1644921072.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [10 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/16/7194-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [11 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/16/29682-1644383600.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [12 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_0_P1/16/10765-1643893942.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 423
# Number of edges in the graph: 422
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9976359338061466
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [13 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_9_P1/24/2832-1643893435.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 16
# Number of neighbors of the root: 26
# ------------------------------------------------------------------------
# Found 2 / 4 keys with a mean reward of 36
# [14 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/32/28078-1643981419.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [15 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/64/2147-1643982079.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [16 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_9_P1/64/8927-1643896258.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 443
# Number of edges in the graph: 442
# Path length from current node to target nodes: 2
# Mean number of neighbors: 0.9977426636568849
# Depth of the graph: 16
# Number of neighbors of the root: 32
# ------------------------------------------------------------------------
# Found 1 / 2 keys with a mean reward of 10
# [17 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_2_P1/24/29613-1643962155.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 440
# Number of edges in the graph: 439
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977272727272727
# Depth of the graph: 16
# Number of neighbors of the root: 32
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of -30
# [18 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_8_P1/64/30433-1643975243.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [19 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_8_P1/64/28768-1643975243.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [20 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/32/4227-1643985447.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [21 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/16/7892-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [22 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/24/21609-1643979482.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [23 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_9_P1/16/5488-1643892554.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 455
# Number of edges in the graph: 454
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9978021978021978
# Depth of the graph: 16
# Number of neighbors of the root: 36
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 30
# [24 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/24/25477-1643980590.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [25 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_8_0_P1/64/18144-1644329935.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 25
# Number of edges in the graph: 24
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.96
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [26 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/64/21072-1644334985.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 315
# Number of edges in the graph: 314
# Path length from current node to target nodes: 10
# Mean number of neighbors: 0.9968253968253968
# Depth of the graph: 10
# Number of neighbors of the root: 2
# ------------------------------------------------------------------------
# Found 1 / 2 keys with a mean reward of 42
# [27 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/24/6233-1644319566.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [28 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/24/27480-1643980590.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [29 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/24/5755-1644319566.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [30 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_9_P1/16/4553-1643892554.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 455
# Number of edges in the graph: 454
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9978021978021978
# Depth of the graph: 16
# Number of neighbors of the root: 36
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 30
# [31 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/17263-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [32 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/32/23024-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [33 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_8_0_P1/16/12424-1644324152.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [34 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/64/11279-1643975276.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [35 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_1_P1/64/24278-1643972914.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 7
# ------------------------------------------------------------------------
# Found 1 / 2 keys with a mean reward of 14
# [36 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_0_P1/64/19250-1643982083.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [37 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_2_P1/32/30499-1643963142.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 447
# Number of edges in the graph: 446
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977628635346756
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [38 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/32/15197-1643978239.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [39 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_8_0_P1/24/8031-1644916021.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [40 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/32/3253-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [41 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_8_0_P1/24/8723-1644916021.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [42 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_2_P1/16/24425-1643898161.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 447
# Number of edges in the graph: 446
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977628635346756
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 36
# [43 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/32/13384-1643978239.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [44 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_0_P1/24/13540-1643980564.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 344
# Number of edges in the graph: 343
# Path length from current node to target nodes: 26
# Mean number of neighbors: 0.997093023255814
# Depth of the graph: 12
# Number of neighbors of the root: 2
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of 64
# [45 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/16/4981-1643982755.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [46 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_0_P1/24/12975-1643896284.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 449
# Number of edges in the graph: 448
# Path length from current node to target nodes: 6
# Mean number of neighbors: 0.9977728285077951
# Depth of the graph: 16
# Number of neighbors of the root: 43
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 8
# [47 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/64/2710-1643982079.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [48 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_8_P1/16/2658-1643891910.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 445
# Number of edges in the graph: 444
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977528089887641
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [49 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_8_P1/64/31647-1643891271.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 446
# Number of edges in the graph: 445
# Path length from current node to target nodes: 2
# Mean number of neighbors: 0.9977578475336323
# Depth of the graph: 16
# Number of neighbors of the root: 33
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 20
# [50 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_0_P1/24/12693-1643896284.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 453
# Number of edges in the graph: 452
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977924944812362
# Depth of the graph: 16
# Number of neighbors of the root: 29
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of 16
# [51 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/17681-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [52 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/16/11236-1644320781.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [53 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/32/13125-1643978239.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [54 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/64/14544-1644315625.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 25
# Number of edges in the graph: 24
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.96
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [55 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/64/15208-1644315625.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 25
# Number of edges in the graph: 24
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.96
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [56 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_7_8_P1/16/12072-1644920217.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [57 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_0_P1/16/8803-1643893942.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [58 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/64/7359-1643986137.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [59 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/64/8757-1643986137.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [60 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/32/2276-1643985447.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [61 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_2_P1/64/5720-1643974139.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 449
# Number of edges in the graph: 448
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977728285077951
# Depth of the graph: 17
# Number of neighbors of the root: 7
# ------------------------------------------------------------------------
# Found 0 / 2 keys with a mean reward of 0
# [62 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_0_P1/16/24202-1643982753.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [63 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_7_8_P1/24/4495-1644395696.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [64 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/16/9472-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [65 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/32/30915-1643981419.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [66 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/16/9775-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [67 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/64/12262-1643975276.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [68 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/32/23309-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [69 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_8_0_P1/64/3413-1644853880.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [70 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/64/14156-1644315625.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 25
# Number of edges in the graph: 24
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.96
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [71 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/32/12929-1643978239.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [72 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_7_8_P1/16/30900-1644391327.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [73 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_7_8_P1/32/18113-1644925018.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [74 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/16/7503-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [75 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/24/31973-1643984444.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [76 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_8_P1/24/28558-1643890740.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 16
# Number of neighbors of the root: 26
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 46
# [77 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/64/8937-1643986137.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [78 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_1_P1/32/21325-1643963138.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 16
# Number of neighbors of the root: 30
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of 16
# [79 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/16/29222-1644383600.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [80 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_7_8_P1/16/12298-1644920217.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [81 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/16/27634-1644383600.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [82 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/17188-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [83 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_7_8_P1/16/1492-1644391327.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [84 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_8_P1/24/11452-1643979488.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 285
# Number of edges in the graph: 284
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9964912280701754
# Depth of the graph: 11
# Number of neighbors of the root: 34
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of 0
# [85 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_1_P1/16/15122-1643898140.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# ...
# Found 4 / 4 keys with a mean reward of 56
# [172 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_7_P1/32/4876-1643985447.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [173 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_8_P1/64/31422-1643891271.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 17
# Number of neighbors of the root: 7
# ------------------------------------------------------------------------
# Found 0 / 2 keys with a mean reward of 0
# [174 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_0_P1/16/22921-1643982753.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [175 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_2_P1/24/27414-1643962155.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 440
# Number of edges in the graph: 439
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977272727272727
# Depth of the graph: 16
# Number of neighbors of the root: 32
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of -30
# [176 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/16554-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [177 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/64/20670-1643986141.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [178 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/scp/V_8_0_P1/32/1398-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [179 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_9_P1/64/8909-1643896258.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 443
# Number of edges in the graph: 442
# Path length from current node to target nodes: 2
# Mean number of neighbors: 0.9977426636568849
# Depth of the graph: 16
# Number of neighbors of the root: 32
# ------------------------------------------------------------------------
# Found 1 / 2 keys with a mean reward of 10
# [180 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_2_P1/24/28417-1643962155.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 440
# Number of edges in the graph: 439
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977272727272727
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 14
# [181 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_8_P1/32/2572-1643978226.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [182 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_1_P1/64/32044-1643982079.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [183 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/16936-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [184 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/16/29106-1644383600.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [185 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/client/V_8_0_P1/16/9660-1644916589.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [186 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_1_P1/24/18335-1643962152.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 449
# Number of edges in the graph: 448
# Path length from current node to target nodes: 6
# Mean number of neighbors: 0.9977728285077951
# Depth of the graph: 16
# Number of neighbors of the root: 43
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 8
# [187 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_0_P1/32/18607-1643981424.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [188 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_6_9_P1/32/7343-1643893921.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 449
# Number of edges in the graph: 448
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977728285077951
# Depth of the graph: 16
# Number of neighbors of the root: 30
# ------------------------------------------------------------------------
# Found 2 / 4 keys with a mean reward of 20
# [189 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_8_0_P1/16/13865-1644324152.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [190 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_0_P1/16/8533-1643893942.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [191 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/16238-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [192 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_8_0_P1/32/15226-1644326802.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [193 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_8_0_P1/16/13568-1644324152.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [194 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/port-forwarding/V_7_8_P1/32/22568-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 42
# [195 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_0_P1/24/14236-1643896284.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 423
# Number of edges in the graph: 422
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9976359338061466
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of 4
# [196 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_7_9_P1/64/10657-1643975276.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [197 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/32/16082-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# [198 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_0_P1/64/19103-1643982083.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 28
# [199 / 200] : Executing Testing for /root/ssh-rlkex/Test_Graphs/basic/V_8_8_P1/16/9934-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 56
# Testing done with a mean reward of 41.42 and a success rate of 0.8075
