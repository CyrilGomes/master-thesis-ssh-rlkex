# %%
# -------------------------
# IMPORTS AND SETUP
# -------------------------

import os
import random
import numpy as np
import networkx as nx
import torch
import torch.nn.functional as F
import torch_geometric
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv, global_mean_pool
from torch_scatter import scatter_max

from rl_env_graph_obs_variable_action_space import GraphTraversalEnv
from collections import deque
import numpy as np
import random
import torch
import torch.nn.functional as F
from torch import optim
from collections import namedtuple, deque
#import range tqdm
from tqdm import tqdm
from tqdm import trange
from torch_geometric.loader import DataLoader
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv, global_mean_pool

from torch_geometric.nn import GCNConv, global_mean_pool, SAGPooling, global_add_pool, global_max_pool
from torch_geometric.data import Data
import torch_geometric.transforms as T
from torch_geometric.nn import GATConv
from torch.utils.tensorboard import SummaryWriter

import heapq  # For priority queue
import time
from agent_variable_action_space import Agent
from utils import preprocess_graph, convert_types, add_global_root_node, connect_components, remove_all_isolated_nodes
from networkx.drawing.nx_pydot import graphviz_layout

# %%
from agent_variable_action_space import GraphQNetwork

STATE_SPACE = 7
EDGE_ATTR_SIZE = 1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GraphQNetwork(STATE_SPACE, EDGE_ATTR_SIZE, 0).to(device)
model_path = "/root/ssh-rlkex/models/model_75_succ.pt"
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
# -------------------------
# HYPERPARAMETERS
# -------------------------

def act(model, state, action_mask, goal, visited_subgraph):
    state = state
    action_mask = action_mask.to(device)
    goal = goal.to(device)
    goal = goal.unsqueeze(0)
    model.eval()
    x = state.x.to(device)
    edge_index = state.edge_index.to(device)
    edge_attr = state.edge_attr.to(device)
    with torch.no_grad():  # Wrap in no_grad
        action_values = model(x, edge_index, edge_attr, None, action_mask, goal, visited_subgraph, None)
    return_values = action_values.cpu()
    selected_action = torch.argmax(return_values).item()
    torch.cuda.empty_cache()
    return selected_action, return_values



def define_targets(graph):
    target_nodes_map = {}
    for node, attributes in graph.nodes(data=True):
        if attributes['cat'] >= 0:
            target_nodes_map[node] = attributes['cat'] 
    return target_nodes_map

# %%
def test_for_graph(file):
    """Basically the same as the training function, but without training"""
    graph = nx.read_graphml(file)
    graph = preprocess_graph(graph)

    #get all target_nodes, check if nodes has 'cat' = 1
    target_nodes = define_targets(graph=graph)
    episode_rewards = []
    #data = graph_to_data(graph)
    env = GraphTraversalEnv(graph, target_nodes, obs_is_full_graph=True)
    
    total_reward = 0
    total_key_found = 0

    for target in target_nodes:
        done = False

        goal = target_nodes[target]
        observation = env.reset()
        goal_one_hot = env.get_goal_one_hot(goal)
        env.set_target_goal(goal)
        display_graph = env.graph
        while not done:
            
            action_mask = env._get_action_mask()
            visited_subgraph = env.get_visited_subgraph()
            action, qvalues = act(model, observation, action_mask, goal_one_hot, visited_subgraph)
            node_qvalues_map = {}
            for i, qvalue in enumerate(qvalues):
                if action_mask[i] == 1:
                    node_qvalues_map[env.inverse_node_mapping[i]] = qvalue
            #if SHOW_GAPH_TEST:
                #show_graph(display_graph, target, env.current_node, node_qvalues_map)
            
            new_observation, reward, done, info, new_goal = env.step(action)
            total_reward += reward
            if done:
                if info["found_target"]:
                    total_key_found += 1
            
            observation = new_observation
    
    return total_reward, total_key_found, len(target_nodes)

# %%
FOLDER = "/root/ssh-rlkex/Generated_Graphs"
#get all files in the folder recursively
all_files = []
for root, dirs, files in os.walk(FOLDER):
    for file in files:
        if file.endswith(".graphml"):
            all_files.append(os.path.join(root, file))


print(f"Total files: {len(all_files)}")
# Out:
# Total files: 8517

# %%
#shuffle the files
random.shuffle(all_files)

nb_test_files = 200
test_files = all_files[:nb_test_files]

# %%
#Test for each file
print(f"Executing Testing ...")
test_rewards = []
test_success_rate = []
for i, file in enumerate(test_files):
    if file.endswith(".graphml"):
        print(f"[{i} / {nb_test_files}] : Executing Testing for {file}")
        reward, nb_found_keys, nb_keys = test_for_graph(file)
        print(f"Found {nb_found_keys} / {nb_keys} keys with a mean reward of {reward}")
        test_rewards.append(reward)
        test_success_rate.append(nb_found_keys / nb_keys)

print(f"Testing done with a mean reward of {np.mean(test_rewards)} and a success rate of {np.mean(test_success_rate)}")
# Out:
# Executing Testing ...
# [0 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_8_0_P1/64/19707-1644329935.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 25
# Number of edges in the graph: 24
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.96
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [1 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/64/30253-1643891271.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 17
# Number of neighbors of the root: 7
# ------------------------------------------------------------------------
# Found 0 / 2 keys with a mean reward of -1.2
# [2 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/16/18460-1643978835.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [3 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/32/16653-1643985448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [4 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/64/5519-1643974139.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 442
# Number of edges in the graph: 441
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.997737556561086
# Depth of the graph: 16
# Number of neighbors of the root: 25
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [5 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_1_P1/32/29046-1643981419.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [6 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_7_8_P1/32/22773-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [7 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/24/4868-1644319566.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [8 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/24/28970-1643962155.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 456
# Number of edges in the graph: 455
# Path length from current node to target nodes: 18
# Mean number of neighbors: 0.9978070175438597
# Depth of the graph: 16
# Number of neighbors of the root: 35
# ------------------------------------------------------------------------
# Found 1 / 6 keys with a mean reward of -0.4999999999999998
# [9 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_8_0_P1/16/9263-1644916589.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [10 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_7_8_P1/32/18587-1644925018.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [11 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/64/12411-1644399999.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 23
# Number of edges in the graph: 22
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9565217391304348
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [12 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/16/29162-1643983765.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [13 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/64/28954-1643975243.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [14 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/32/1126-1643978226.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [15 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/64/7843-1643986137.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [16 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/16/11516-1644320781.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [17 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/32/934-1643978226.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [18 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/16/9121-1643983796.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [19 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_1_P1/64/596-1643982079.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [20 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_8_0_P1/24/24085-1644325130.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [21 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/64/11652-1643975276.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [22 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/16/4225-1643978841.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [23 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/16/4021-1643978841.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [24 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/16/16976-1643978835.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [25 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/24/26232-1643890740.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 16
# Number of neighbors of the root: 26
# ------------------------------------------------------------------------
# Found 5 / 6 keys with a mean reward of 5.799999999999999
# [26 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/64/27977-1643975243.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [27 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_0_P1/64/21033-1643897382.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 7
# ------------------------------------------------------------------------
# Found 1 / 2 keys with a mean reward of 0.8
# [28 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_1_P1/64/25047-1643972914.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 6
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 16
# Number of neighbors of the root: 28
# ------------------------------------------------------------------------
# Found 0 / 2 keys with a mean reward of -0.3999999999999999
# [29 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/64/29754-1643891271.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 446
# Number of edges in the graph: 445
# Path length from current node to target nodes: 2
# Mean number of neighbors: 0.9977578475336323
# Depth of the graph: 16
# Number of neighbors of the root: 33
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2
# [30 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/32/22541-1643890088.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 16
# Number of neighbors of the root: 29
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 1.0
# [31 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/64/30094-1643891271.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 446
# Number of edges in the graph: 445
# Path length from current node to target nodes: 2
# Mean number of neighbors: 0.9977578475336323
# Depth of the graph: 16
# Number of neighbors of the root: 33
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2
# [32 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/24/6408-1644319566.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [33 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/32/4432-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [34 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/24/30252-1643962155.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 456
# Number of edges in the graph: 455
# Path length from current node to target nodes: 18
# Mean number of neighbors: 0.9978070175438597
# Depth of the graph: 16
# Number of neighbors of the root: 35
# ------------------------------------------------------------------------
# Found 1 / 6 keys with a mean reward of -0.4999999999999998
# [35 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/24/4116-1644395696.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [36 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_8_0_P1/64/17695-1644329935.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 25
# Number of edges in the graph: 24
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.96
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [37 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_0_P1/32/16310-1643981424.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [38 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/64/7688-1643974139.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 442
# Number of edges in the graph: 441
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.997737556561086
# Depth of the graph: 16
# Number of neighbors of the root: 25
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [39 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/64/7726-1643986137.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [40 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/64/28635-1643975243.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [41 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/24/1479-1643984444.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [42 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/32/7351-1644398480.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [43 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/32/1338-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [44 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/64/9768-1644399999.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [45 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_1_P1/24/25047-1643980590.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [46 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/24/13209-1643984448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 269
# Number of edges in the graph: 268
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9962825278810409
# Depth of the graph: 8
# Number of neighbors of the root: 59
# ------------------------------------------------------------------------
# Found 0 / 6 keys with a mean reward of -3.0
# [47 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_7_8_P1/32/23056-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [48 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/32/303-1643963142.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 445
# Number of edges in the graph: 444
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977528089887641
# Depth of the graph: 16
# Number of neighbors of the root: 36
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of -0.7999999999999998
# [49 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_0_P1/32/16069-1643896819.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of -0.19999999999999996
# [50 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_1_P1/24/19342-1643962152.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 453
# Number of edges in the graph: 452
# Path length from current node to target nodes: 18
# Mean number of neighbors: 0.9977924944812362
# Depth of the graph: 16
# Number of neighbors of the root: 29
# ------------------------------------------------------------------------
# Found 0 / 6 keys with a mean reward of -2.3
# [51 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_9_P1/24/1065-1643893435.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 16
# Number of neighbors of the root: 26
# ------------------------------------------------------------------------
# Found 4 / 6 keys with a mean reward of 3.6999999999999997
# [52 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/24/12058-1643984448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [53 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_7_8_P1/32/18163-1644925018.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.96875
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [54 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/16/24212-1643898161.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of -2.0
# [55 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_8_0_P1/24/9003-1644916021.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [56 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/32/4033-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [57 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/24/27774-1643890740.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 448
# Number of edges in the graph: 447
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977678571428571
# Depth of the graph: 16
# Number of neighbors of the root: 26
# ------------------------------------------------------------------------
# Found 5 / 6 keys with a mean reward of 5.799999999999999
# [58 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/32/2324-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [59 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_0_P1/32/17544-1643896819.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 423
# Number of edges in the graph: 422
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9976359338061466
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 3 / 4 keys with a mean reward of 3.4000000000000004
# [60 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/16/6549-1643978841.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [61 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_1_P1/16/4981-1643982755.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [62 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_0_P1/32/18742-1643981424.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [63 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/64/18209-1643986141.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [64 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_7_8_P1/24/14302-1644921072.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [65 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_8_0_P1/24/24937-1644325130.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [66 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_8_0_P1/16/11588-1644916589.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [67 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_8_0_P1/32/15246-1644326802.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [68 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/32/21652-1643890088.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 445
# Number of edges in the graph: 444
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977528089887641
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 4 keys with a mean reward of 1.6
# [69 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/16/25221-1643898161.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 16
# Number of neighbors of the root: 37
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of -0.9999999999999999
# [70 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_0_P1/64/19250-1643982083.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [71 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/16/29649-1643983765.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [72 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/16/22496-1643898161.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of -0.19999999999999996
# [73 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_8_P1/24/8302-1643979488.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 285
# Number of edges in the graph: 284
# Path length from current node to target nodes: 6
# Mean number of neighbors: 0.9964912280701754
# Depth of the graph: 11
# Number of neighbors of the root: 34
# ------------------------------------------------------------------------
# Found 0 / 6 keys with a mean reward of -3.0
# [74 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/24/31281-1643984444.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [75 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/32/31663-1643963142.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 16
# Number of neighbors of the root: 37
# ------------------------------------------------------------------------
# Found 0 / 4 keys with a mean reward of -0.9999999999999999
# [76 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_1_P1/16/4996-1643982755.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [77 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/32/2438-1643985447.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [78 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_7_P1/24/32276-1643984444.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [79 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_7_8_P1/32/23649-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [80 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_8_P1/32/23926-1643890088.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 445
# Number of edges in the graph: 444
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9977528089887641
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 4 keys with a mean reward of 1.6
# [81 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_7_8_P1/32/24030-1644338891.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [82 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_1_P1/64/557-1643982079.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [83 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/24/5169-1644395696.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# ...
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 455
# Number of edges in the graph: 454
# Path length from current node to target nodes: 18
# Mean number of neighbors: 0.9978021978021978
# Depth of the graph: 16
# Number of neighbors of the root: 28
# ------------------------------------------------------------------------
# Found 2 / 6 keys with a mean reward of 1.5
# [173 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_8_0_P1/32/3794-1644317824.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 28
# Number of edges in the graph: 27
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9642857142857143
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [174 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_8_0_P1/32/5507-1644913417.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [175 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/64/11332-1644399999.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 23
# Number of edges in the graph: 22
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9565217391304348
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [176 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/64/19339-1643986141.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 34
# Number of edges in the graph: 33
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9705882352941176
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [177 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/32/14714-1643978239.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [178 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_1_P1/16/12730-1643898140.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of -0.19999999999999996
# [179 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_9_P1/16/7630-1643892554.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 449
# Number of edges in the graph: 448
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977728285077951
# Depth of the graph: 16
# Number of neighbors of the root: 30
# ------------------------------------------------------------------------
# Found 2 / 4 keys with a mean reward of 0.5
# [180 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/64/12838-1643975276.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [181 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_8_0_P1/16/12613-1644324152.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [182 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_9_P1/24/3268-1643893435.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 452
# Number of edges in the graph: 451
# Path length from current node to target nodes: 18
# Mean number of neighbors: 0.9977876106194691
# Depth of the graph: 16
# Number of neighbors of the root: 35
# ------------------------------------------------------------------------
# Found 1 / 6 keys with a mean reward of -0.8
# [183 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_1_P1/16/13851-1643898140.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 421
# Number of edges in the graph: 420
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.997624703087886
# Depth of the graph: 17
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of -0.19999999999999996
# [184 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_0_P1/24/11670-1643980564.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 344
# Number of edges in the graph: 343
# Path length from current node to target nodes: 39
# Mean number of neighbors: 0.997093023255814
# Depth of the graph: 12
# Number of neighbors of the root: 2
# ------------------------------------------------------------------------
# Found 0 / 6 keys with a mean reward of -0.30000000000000004
# [185 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/client/V_8_0_P1/24/8831-1644916021.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [186 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_6_9_P1/16/4201-1643892554.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 455
# Number of edges in the graph: 454
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9978021978021978
# Depth of the graph: 16
# Number of neighbors of the root: 36
# ------------------------------------------------------------------------
# Found 1 / 4 keys with a mean reward of 1.0
# [187 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/64/11589-1643975276.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 2
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [188 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_0_P1/24/13120-1643896284.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 453
# Number of edges in the graph: 452
# Path length from current node to target nodes: 18
# Mean number of neighbors: 0.9977924944812362
# Depth of the graph: 16
# Number of neighbors of the root: 29
# ------------------------------------------------------------------------
# Found 0 / 6 keys with a mean reward of -2.3
# [189 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_7_8_P1/24/25466-1644344888.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [190 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/24/20410-1643979482.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [191 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/16/30226-1644391327.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 33
# Number of edges in the graph: 32
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9696969696969697
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [192 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/port-forwarding/V_7_8_P1/64/20867-1644334985.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [193 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/32/6849-1644398480.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 29
# Number of edges in the graph: 28
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9655172413793104
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [194 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_0_P1/16/23186-1643982753.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# [195 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_1_P1/32/21493-1643963138.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 451
# Number of edges in the graph: 450
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.9977827050997783
# Depth of the graph: 16
# Number of neighbors of the root: 30
# ------------------------------------------------------------------------
# Found 2 / 4 keys with a mean reward of 2.6
# [196 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_8_8_P1/24/12227-1643984448.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 6
# Number of nodes in the graph: 32
# Number of edges in the graph: 31
# Path length from current node to target nodes: 12
# Mean number of neighbors: 0.96875
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 6 / 6 keys with a mean reward of 7.8
# [197 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/scp/V_7_8_P1/64/10649-1644399999.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 24
# Number of edges in the graph: 23
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9583333333333334
# Depth of the graph: 3
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 2 / 2 keys with a mean reward of 2.6
# [198 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_2_P1/64/6042-1643974139.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 2
# Number of nodes in the graph: 449
# Number of edges in the graph: 448
# Path length from current node to target nodes: 4
# Mean number of neighbors: 0.9977728285077951
# Depth of the graph: 16
# Number of neighbors of the root: 33
# ------------------------------------------------------------------------
# Found 1 / 2 keys with a mean reward of 0.6000000000000001
# [199 / 200] : Executing Testing for /root/ssh-rlkex/Generated_Graphs/basic/V_7_9_P1/32/12998-1643978239.graphml
# Model loaded!
# -------------------- ASSESSING TARGET COMPLEXITY ----------------------
# Has cycles: False
# Number of targets: 4
# Number of nodes in the graph: 30
# Number of edges in the graph: 29
# Path length from current node to target nodes: 8
# Mean number of neighbors: 0.9666666666666667
# Depth of the graph: 4
# Number of neighbors of the root: 9
# ------------------------------------------------------------------------
# Found 4 / 4 keys with a mean reward of 5.2
# Testing done with a mean reward of 3.7815 and a success rate of 0.77875
